# %%
import pandas as pd
import seaborn as sns

# %%
body_df = pd.read_csv('../data/body.csv', index_col=0)
body_df.head()
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0

# %%
sns.regplot(data=body_df, x='Height', y='Weight')
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>
